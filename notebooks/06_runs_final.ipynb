# %%
""" External Imports """
import maboss
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import shutil
import sys
import yaml
import numpy as np
sys.path.append("/Users/emilieyu/endotehelial-masboss")

from boolean_models.scripts.run_perturbations import run_perturbations
from boolean_models.scripts.run_param_sweep import *
# Out:
# ipylab module is not installed, menus and toolbar are disabled.

# %%
""" Global Setting Configuration """

PROJECT_ROOT = Path("/Users/emilieyu/endotehelial-masboss/")
CONFIG_PATH = PROJECT_ROOT / "config" / "rho_sim_config.yaml"
SWEEP_CONFIG_PATH = PROJECT_ROOT / "config" / "parameter_sweep_config.yaml"

with open(CONFIG_PATH, "r") as f:
    config = yaml.safe_load(f)

with open(SWEEP_CONFIG_PATH, "r") as f:
    sweep_config = yaml.safe_load(f)

# MaBoSS Model files
MODELS_BND = PROJECT_ROOT / config['paths']['model_bnd']
MODELS_CFG = PROJECT_ROOT / config['paths']['model_cfg']

# Result directory
RESULTS_DIR = PROJECT_ROOT / config['paths']['results_base'] 

# Subdirectories to store parameter sweep / perturbation result
PARAM_DIR = RESULTS_DIR / config['paths']['subdirs']['param_sweep']
PERBS_DIR = RESULTS_DIR / config['paths']['subdirs']['perturbation_sim']

PARAM_DIR.mkdir(parents=True, exist_ok=True)
PERBS_DIR.mkdir(parents=True, exist_ok=True)

# %%
""" Setup base model. """
base_model = maboss.load(str(MODELS_BND), str(MODELS_CFG))
base_model.param['max_time'] = 10.0
base_model.param['sample_count'] = 5000

# %% [markdown]
# ## Run Perturbations and Parameter Sweeps

# %%
perb_df = run_perturbations(base_model, PERBS_DIR, config)
perb_df
# Out:
# DEBUG: Running perturbation: WT
# DEBUG: Running perturbation: DSP
# DEBUG: Running perturbation: TJP1
# DEBUG: Running perturbation: JCAD
# DEBUG: Running perturbation: DSP_JCAD
# DEBUG: Running perturbation: TJP1_JCAD
# DEBUG: All simulations completed successfully
# DEBUG: File perturbation_timeseries.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/perturbation_sim
#        t       DSP      TJP1      JCAD      RhoA      RhoC perturbation  \
# 0    0.0  0.494801  0.487001  0.502400  0.523715  0.535092           WT
# 1    0.1  0.494801  0.487000  0.502399  0.536110  0.546405           WT
# 2    0.2  0.494801  0.487000  0.502402  0.542754  0.544444           WT
# 3    0.3  0.494799  0.487000  0.502401  0.546061  0.549899           WT
# 4    0.4  0.494799  0.487000  0.502400  0.545326  0.550791           WT
# ..   ...       ...       ...       ...       ...       ...          ...
# 595  9.5  0.498201  0.000000  0.000000  0.580651  0.378367    TJP1_JCAD
# 596  9.6  0.498201  0.000000  0.000000  0.579680  0.378972    TJP1_JCAD
# 597  9.7  0.498200  0.000000  0.000000  0.579726  0.381091    TJP1_JCAD
# 598  9.8  0.498200  0.000000  0.000000  0.584270  0.382609    TJP1_JCAD
# 599  9.9  0.498200  0.000000  0.000000  0.586034  0.378510    TJP1_JCAD
#
#         delta phenotype
# 0    0.011377    Normal
# 1    0.010295    Normal
# 2    0.001690    Normal
# 3    0.003838    Normal
# 4    0.005465    Normal
# ..        ...       ...
# 595 -0.202284    Normal
# 596 -0.200708    Normal
# 597 -0.198635    Normal
# 598 -0.201661    Normal
# 599 -0.207524    Normal
#
# [600 rows x 9 columns]

# %%
sweep_results = run_sweeps(base_model, PARAM_DIR, sweep_config, config)

#sweep_results = run_sweeps(base_model, PARAM_DIR, sweep_config, config)
# Out:
# >>> DEBUG: Initialising: WT_Sweep (1D)
# DEBUG: Starting WT_Sweep sweep for perturbation: WT with dict_keys(['$RhoA_amp', '$RhoA_mod', '$RhoA_basal', '$RhoA_antagonistic', '$RhoA_decay', '$RhoC_amp', '$RhoC_mod', '$RhoC_basal', '$RhoC_antagonistic', '$RhoC_decay'])
# DEBUG: Completed WT_Sweep sweep for perturbation: WT
# DEBUG: File 1D_WT_Sweep.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: WT_Sweep successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: DSP_Sweep (1D)
# DEBUG: Starting DSP_Sweep sweep for perturbation: DSP with ['$RhoC_antagonistic', '$RhoC_mod', '$RhoC_amp', '$RhoC_decay']
# DEBUG: Completed DSP_Sweep sweep for perturbation: DSP
# DEBUG: File 1D_DSP_Sweep.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: DSP_Sweep successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: TJP1_Sweep (1D)
# DEBUG: Starting TJP1_Sweep sweep for perturbation: TJP1 with ['$RhoA_antagonistic', '$RhoA_mod', '$RhoA_amp', '$RhoA_decay']
# DEBUG: Completed TJP1_Sweep sweep for perturbation: TJP1
# DEBUG: File 1D_TJP1_Sweep.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: TJP1_Sweep successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: JCAD_Sweep (1D)
# DEBUG: Starting JCAD_Sweep sweep for perturbation: JCAD with ['$RhoA_mod', '$RhoC_mod', '$RhoA_basal', '$RhoC_basal']
# DEBUG: Completed JCAD_Sweep sweep for perturbation: JCAD
# DEBUG: File 1D_JCAD_Sweep.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: JCAD_Sweep successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: DSP_JCAD_Sweep (1D)
# DEBUG: Starting DSP_JCAD_Sweep sweep for perturbation: DSP_JCAD with ['$RhoC_mod', '$RhoC_basal', '$RhoA_basal']
# DEBUG: Completed DSP_JCAD_Sweep sweep for perturbation: DSP_JCAD
# DEBUG: File 1D_DSP_JCAD_Sweep.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: DSP_JCAD_Sweep successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: DSP_TJP1_Sweep (1D)
# DEBUG: Starting DSP_TJP1_Sweep sweep for perturbation: DSP_TJP1 with ['$RhoA_mod', '$RhoA_basal', '$RhoC_basal']
# ERROR: Failed experiment DSP_TJP1_Sweep: 'DSP_TJP1'
#
# >>> DEBUG: Initialising: Competition_Landscape (2D)
# DEBUG: Starting Competition_Landscape sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.], $RhoC_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: WT
# DEBUG: Starting Competition_Landscape sweep for perturbation: TJP1
# DEBUG: Computed values: $RhoA_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.], $RhoC_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: TJP1
# DEBUG: Starting Competition_Landscape sweep for perturbation: DSP
# DEBUG: Computed values: $RhoA_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.], $RhoC_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: DSP
# DEBUG: File 2D_Competition_Landscape.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: Competition_Landscape successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: Escape_Threshold_RhoA (2D)
# DEBUG: Starting Escape_Threshold_RhoA sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoA_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Escape_Threshold_RhoA sweep for perturbation: WT
# DEBUG: Starting Escape_Threshold_RhoA sweep for perturbation: TJP1
# DEBUG: Computed values: $RhoA_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoA_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Escape_Threshold_RhoA sweep for perturbation: TJP1
# DEBUG: File 2D_Escape_Threshold_RhoA.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: Escape_Threshold_RhoA successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: Escape_Threshold_RhoC (2D)
# DEBUG: Starting Escape_Threshold_RhoC sweep for perturbation: WT
# DEBUG: Computed values: $RhoC_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoC_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Escape_Threshold_RhoC sweep for perturbation: WT
# DEBUG: Starting Escape_Threshold_RhoC sweep for perturbation: DSP
# DEBUG: Computed values: $RhoC_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoC_antagonistic: [ 1.  3.  5.  7.  9. 11. 13. 15.]
# DEBUG: Completed Escape_Threshold_RhoC sweep for perturbation: DSP
# DEBUG: File 2D_Escape_Threshold_RhoC.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: Escape_Threshold_RhoC successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: Amplification_Gain_RhoA (2D)
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoA_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: WT
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: JCAD
# DEBUG: Computed values: $RhoA_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoA_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: JCAD
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: TJP1_JCAD
# DEBUG: Computed values: $RhoA_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoA_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: TJP1_JCAD
# DEBUG: File 2D_Amplification_Gain_RhoA.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: Amplification_Gain_RhoA successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
#
# >>> DEBUG: Initialising: Amplification_Gain_RhoC (2D)
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: WT
# DEBUG: Computed values: $RhoC_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoC_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: WT
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: JCAD
# DEBUG: Computed values: $RhoC_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoC_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: JCAD
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: DSP_JCAD
# DEBUG: Computed values: $RhoC_amp: [ 5. 10. 15. 20. 25. 30. 35.], $RhoC_mod: [0.5 1.  1.5 2.  2.5 3.  3.5 4. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: DSP_JCAD
# DEBUG: File 2D_Amplification_Gain_RhoC.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# >>> DEBUG: Amplification_Gain_RhoC successfully saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# DEBUG: File param_sweep_full.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
# DEBUG: Combined parameter sweep experiment data saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/final/rho_v3/param_sweep
