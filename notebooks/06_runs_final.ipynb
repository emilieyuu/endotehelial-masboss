# %%
""" External Imports """
import maboss
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import shutil
import sys
import yaml
import numpy as np
sys.path.append("/Users/emilieyu/endotehelial-masboss")

from boolean_models.scripts.run_perturbations import run_perturbations
from boolean_models.scripts.run_param_sweep import *
# Out:
# ipylab module is not installed, menus and toolbar are disabled.

# %%
""" Global Setting Configuration """

PROJECT_ROOT = Path("/Users/emilieyu/endotehelial-masboss/")
CONFIG_PATH = PROJECT_ROOT / "config" / "rho_sim_config.yaml"
SWEEP_CONFIG_PATH = PROJECT_ROOT / "config" / "parameter_sweep_config.yaml"

with open(CONFIG_PATH, "r") as f:
    config = yaml.safe_load(f)

with open(SWEEP_CONFIG_PATH, "r") as f:
    sweep_config = yaml.safe_load(f)

# MaBoSS Model files
MODELS_BND = PROJECT_ROOT / config['paths']['model_bnd']
MODELS_CFG = PROJECT_ROOT / config['paths']['model_cfg']

# Result directory
RESULTS_DIR = PROJECT_ROOT / config['paths']['results_base'] 

# Subdirectories to store parameter sweep / perturbation result
PARAM_DIR = RESULTS_DIR / config['paths']['subdirs']['param_sweep']
PERBS_DIR = RESULTS_DIR / config['paths']['subdirs']['perturbation_sim']

PARAM_DIR.mkdir(parents=True, exist_ok=True)
PERBS_DIR.mkdir(parents=True, exist_ok=True)

# %%
""" Setup base model. """
base_model = maboss.load(str(MODELS_BND), str(MODELS_CFG))
base_model.param['max_time'] = 10.0
base_model.param['sample_count'] = 5000

# %% [markdown]
# ## Run Perturbations and Parameter Sweeps

# %%
perb_df = run_perturbations(base_model, PERBS_DIR, config)
perb_df
# Out:
# DEBUG: Running perturbation: WT
# DEBUG: Running perturbation: DSP_KO
# DEBUG: Running perturbation: TJP1_KO
# DEBUG: Running perturbation: JCAD_KO
# DEBUG: Running perturbation: DSP_JCAD_DKO
# DEBUG: Running perturbation: TJP1_JCAD_DKO
# DEBUG: All simulations completed successfully
# DEBUG: File perturbation_timeseries.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/rho_v3/perturbation_sim
#        t       DSP      TJP1      JCAD      RhoA      RhoC   perturbation  \
# 0    0.0  0.504599  0.504798  0.493999  0.525278  0.509717             WT
# 1    0.1  0.504601  0.504800  0.494001  0.546403  0.538359             WT
# 2    0.2  0.504598  0.504798  0.493999  0.547488  0.543567             WT
# 3    0.3  0.504599  0.504800  0.494000  0.549883  0.535518             WT
# 4    0.4  0.504598  0.504799  0.494000  0.554791  0.539166             WT
# ..   ...       ...       ...       ...       ...       ...            ...
# 595  9.5  0.504400  0.000000  0.000000  0.592899  0.373228  TJP1_JCAD_DKO
# 596  9.6  0.504400  0.000000  0.000000  0.591087  0.378458  TJP1_JCAD_DKO
# 597  9.7  0.504400  0.000000  0.000000  0.595745  0.381597  TJP1_JCAD_DKO
# 598  9.8  0.504400  0.000000  0.000000  0.597451  0.381952  TJP1_JCAD_DKO
# 599  9.9  0.504400  0.000000  0.000000  0.593395  0.386108  TJP1_JCAD_DKO
#
#         delta phenotype
# 0   -0.015561    Normal
# 1   -0.008044    Normal
# 2   -0.003921    Normal
# 3   -0.014365    Normal
# 4   -0.015625    Normal
# ..        ...       ...
# 595 -0.219671    Normal
# 596 -0.212629    Normal
# 597 -0.214148    Normal
# 598 -0.215499    Normal
# 599 -0.207287    Normal
#
# [600 rows x 9 columns]

# %%
sweep_results = run_sweeps(base_model, PARAM_DIR, sweep_config, config)

#sweep_results = run_sweeps(base_model, PARAM_DIR, sweep_config, config)
# Out:
# >>> DEBUG: Initialising: WT_Sweep (1D)
# DEBUG: Starting WT_Sweep sweep for perturbation: WT with dict_keys(['$RhoA_amp', '$RhoA_mod', '$RhoA_basal', '$RhoA_antagonistic', '$RhoA_decay', '$RhoC_amp', '$RhoC_mod', '$RhoC_basal', '$RhoC_antagonistic', '$RhoC_decay'])
# DEBUG: Completed WT_Sweep sweep for perturbation: WT
#
# >>> DEBUG: Initialising: DSP_Sweep (1D)
# DEBUG: Starting DSP_Sweep sweep for perturbation: DSP_KO with ['$RhoC_antagonistic', '$RhoC_mod', '$RhoC_amp', '$RhoC_decay']
# DEBUG: Completed DSP_Sweep sweep for perturbation: DSP_KO
#
# >>> DEBUG: Initialising: TJP1_Sweep (1D)
# DEBUG: Starting TJP1_Sweep sweep for perturbation: TJP1_KO with ['$RhoA_antagonistic', '$RhoA_mod', '$RhoA_amp', '$RhoA_decay']
# DEBUG: Completed TJP1_Sweep sweep for perturbation: TJP1_KO
#
# >>> DEBUG: Initialising: JCAD_Sweep (1D)
# DEBUG: Starting JCAD_Sweep sweep for perturbation: JCAD_KO with ['$RhoA_mod', '$RhoC_mod', '$RhoA_basal', '$RhoC_basal']
# DEBUG: Completed JCAD_Sweep sweep for perturbation: JCAD_KO
#
# >>> DEBUG: Initialising: DSP_JCAD_Sweep (1D)
# DEBUG: Starting DSP_JCAD_Sweep sweep for perturbation: DSP_JCAD_DKO with ['$RhoC_mod', '$RhoC_basal', '$RhoA_basal']
# DEBUG: Completed DSP_JCAD_Sweep sweep for perturbation: DSP_JCAD_DKO
#
# >>> DEBUG: Initialising: TJP1_JCAD_Sweep (1D)
# DEBUG: Starting TJP1_JCAD_Sweep sweep for perturbation: TJP1_JCAD_DKO with ['$RhoA_mod', '$RhoA_basal', '$RhoC_basal']
# DEBUG: Completed TJP1_JCAD_Sweep sweep for perturbation: TJP1_JCAD_DKO
#
# >>> DEBUG: Initialising: DSP_TJP1_Sweep (1D)
# DEBUG: Starting DSP_TJP1_Sweep sweep for perturbation: DSP_TJP1_DKO with ['$RhoA_basal', '$RhoC_basal']
# ERROR: Failed experiment DSP_TJP1_Sweep: 'DSP_TJP1_DKO'
#
# >>> DEBUG: Initialising: Competition_Landscape (2D)
# DEBUG: Starting Competition_Landscape sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.], $RhoC_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: WT
# DEBUG: Starting Competition_Landscape sweep for perturbation: TJP1_KO
# DEBUG: Computed values: $RhoA_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.], $RhoC_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: TJP1_KO
# DEBUG: Starting Competition_Landscape sweep for perturbation: DSP_KO
# DEBUG: Computed values: $RhoA_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.], $RhoC_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Competition_Landscape sweep for perturbation: DSP_KO
#
# >>> DEBUG: Initialising: Escape_Threshold_RhoA (2D)
# DEBUG: Starting Escape_Threshold_RhoA sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoA_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Escape_Threshold_RhoA sweep for perturbation: WT
# DEBUG: Starting Escape_Threshold_RhoA sweep for perturbation: TJP1_KO
# DEBUG: Computed values: $RhoA_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoA_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Escape_Threshold_RhoA sweep for perturbation: TJP1_KO
#
# >>> DEBUG: Initialising: Escape_Threshold_RhoC (2D)
# DEBUG: Starting Escape_Threshold_RhoC sweep for perturbation: WT
# DEBUG: Computed values: $RhoC_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoC_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Escape_Threshold_RhoC sweep for perturbation: WT
# DEBUG: Starting Escape_Threshold_RhoC sweep for perturbation: DSP_KO
# DEBUG: Computed values: $RhoC_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoC_antagonistic: [ 0.  2.  4.  6.  8. 10. 12. 14.]
# DEBUG: Completed Escape_Threshold_RhoC sweep for perturbation: DSP_KO
#
# >>> DEBUG: Initialising: Amplification_Gain_RhoA (2D)
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoA_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: WT
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: JCAD_KO
# DEBUG: Computed values: $RhoA_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoA_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: JCAD_KO
# DEBUG: Starting Amplification_Gain_RhoA sweep for perturbation: TJP1_JCAD_DKO
# DEBUG: Computed values: $RhoA_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoA_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoA sweep for perturbation: TJP1_JCAD_DKO
#
# >>> DEBUG: Initialising: Amplification_Gain_RhoC (2D)
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: WT
# DEBUG: Computed values: $RhoC_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoC_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: WT
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: JCAD_KO
# DEBUG: Computed values: $RhoC_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoC_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: JCAD_KO
# DEBUG: Starting Amplification_Gain_RhoC sweep for perturbation: DSP_JCAD_DKO
# DEBUG: Computed values: $RhoC_amp: [ 0.  5. 10. 15. 20. 25. 30. 35. 40. 45.], $RhoC_mod: [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5. ]
# DEBUG: Completed Amplification_Gain_RhoC sweep for perturbation: DSP_JCAD_DKO
#
# >>> DEBUG: Initialising: Basal_Activity_Robustness (2D)
# DEBUG: Starting Basal_Activity_Robustness sweep for perturbation: WT
# DEBUG: Computed values: $RhoA_basal: [0.  0.4 0.8 1.2], $RhoC_basal: [0.  0.4 0.8 1.2]
# DEBUG: Completed Basal_Activity_Robustness sweep for perturbation: WT
# DEBUG: File param_sweep_full.csv successfully written to directory: /Users/emilieyu/endotehelial-masboss/results/boolean_models/rho_v3/param_sweep
# DEBUG: Combined parameter sweep experiment data saved to /Users/emilieyu/endotehelial-masboss/results/boolean_models/rho_v3/param_sweep
