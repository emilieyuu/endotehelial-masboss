# %%
import pandas as pd
import sys
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpatches 
sys.path.append("/Users/emilieyu/endotehelial-masboss")

from src.paths import EXP_DIR
EXP_DIR
# Out:
# PosixPath('/Users/emilieyu/endotehelial-masboss/CSV_Files/Elongation')

# %%
print(EXP_DIR)
print(EXP_DIR.exists())
print(list(EXP_DIR.glob("*")))
# Out:
# /Users/emilieyu/endotehelial-masboss/CSV_Files/Elongation
# True
# ...

# %%
wt_csv = EXP_DIR / "siCONT_001.csv"
dsp_ko_csv = EXP_DIR / "siDSP.csv"
tjp1_ko_csv = EXP_DIR / "siTJP1.csv"

print(dsp_ko_csv)
print(type(dsp_ko_csv))
print(dsp_ko_csv.exists())
# Out:
# /Users/emilieyu/endotehelial-masboss/CSV_Files/Elongation/siDSP.csv
# <class 'pathlib.PosixPath'>
# True

# %%
wt_df = pd.read_csv(wt_csv)
dsp_ko_df = pd.read_csv(dsp_ko_csv)
tjp1_ko_df = pd.read_csv(tjp1_ko_csv)

wt_ar_mean = wt_df['Major/Minor Ratio'].mean()
dsp_ar_mean = dsp_ko_df['Major/Minor Ratio'].mean()
tjp1_ar_mean = tjp1_ko_df['Major/Minor Ratio'].mean()
print(f"WT AR Mean: {wt_ar_mean}")
print(f"DSP KO AR Mean: {dsp_ar_mean}")
print(f"TJP1 KO AR Mean: {tjp1_ar_mean}")
wt_df
# Out:
# WT AR Mean: 5.592069944118363
# DSP KO AR Mean: 7.046723423019233
# TJP1 KO AR Mean: 3.371328936093925
#       Label   Centroid_Y   Centroid_X  Major/Minor Ratio  Major Axis Length  \
# 0        80    32.497813  1626.787901           4.267978          88.068277
# 1        82    75.774142  1075.353875           4.761166         170.819025
# 2        83    66.620061   857.080685           4.228190         141.461477
# 3        84   157.454990  3192.883105          11.545983         312.915981
# 4        85   111.294788  3237.595789           9.130515         196.401794
# ...     ...          ...          ...                ...                ...
# 2010   2881  2831.758651  1069.655709           2.729613          92.676802
# 2011   2883  2831.940189  1666.610155           2.849447          95.482207
# 2012   2893  2838.155768  1483.272777           6.268908         215.329577
# 2013   2894  2831.265768  1605.077089           2.326911          79.467875
# ...

# %%
wt_df['Major/Minor Ratio'].mean()
# Out:
# np.float64(5.592069944118363)

# %%
dsp_ko_df = pd.read_csv(dsp_ko_csv)
dsp_ko_df
# Out:
#       Label   Centroid_Y   Centroid_X  Major/Minor Ratio  Major Axis Length  \
# 0        82   123.857792  1076.554507           4.402797         266.211929
# 1        83    56.840256  3302.122045           9.391793         145.821353
# 2        84   127.722538  2977.609164          22.692132         412.361478
# 3        85    35.563549  3376.587530           3.227264          71.978474
# 4        86    53.867444   674.304404           4.793355         210.480393
# ...     ...          ...          ...                ...                ...
# 2401   3473  2831.526728  2306.760756           1.612556          58.868310
# 2402   3475  2835.168308  2477.413276           5.409153         130.893744
# 2403   3480  2840.622439   438.860976           6.223055         135.103498
# 2404   3484  2832.851137  1721.364576           7.154605         116.302059
# 2405   3490  2846.586272   620.176775           8.162010         161.015672
#
#       Minor Axis Length   Perimeter    Area  Circularity
# ...
